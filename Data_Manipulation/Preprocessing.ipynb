# %%
pip install mne
# Out:
# Collecting mne
#   Downloading mne-1.9.0-py3-none-any.whl.metadata (20 kB)
# Requirement already satisfied: decorator in /usr/local/lib/python3.11/dist-packages (from mne) (4.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from mne) (3.1.6)
# Requirement already satisfied: lazy-loader>=0.3 in /usr/local/lib/python3.11/dist-packages (from mne) (0.4)
# Requirement already satisfied: matplotlib>=3.6 in /usr/local/lib/python3.11/dist-packages (from mne) (3.10.0)
# Requirement already satisfied: numpy<3,>=1.23 in /usr/local/lib/python3.11/dist-packages (from mne) (2.0.2)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from mne) (24.2)
# Requirement already satisfied: pooch>=1.5 in /usr/local/lib/python3.11/dist-packages (from mne) (1.8.2)
# Requirement already satisfied: scipy>=1.9 in /usr/local/lib/python3.11/dist-packages (from mne) (1.15.2)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (from mne) (4.67.1)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.6->mne) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.6->mne) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.6->mne) (4.57.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.6->mne) (1.4.8)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.6->mne) (11.2.1)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.6->mne) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.6->mne) (2.9.0.post0)
# Requirement already satisfied: platformdirs>=2.5.0 in /usr/local/lib/python3.11/dist-packages (from pooch>=1.5->mne) (4.3.7)
# Requirement already satisfied: requests>=2.19.0 in /usr/local/lib/python3.11/dist-packages (from pooch>=1.5->mne) (2.32.3)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->mne) (3.0.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.7->matplotlib>=3.6->mne) (1.17.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests>=2.19.0->pooch>=1.5->mne) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests>=2.19.0->pooch>=1.5->mne) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests>=2.19.0->pooch>=1.5->mne) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests>=2.19.0->pooch>=1.5->mne) (2025.4.26)
# Downloading mne-1.9.0-py3-none-any.whl (7.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.4/7.4 MB 14.9 MB/s eta 0:00:00
# Installing collected packages: mne
# Successfully installed mne-1.9.0

# %%
pip install pyedflib
# Out:
# Collecting pyedflib
#   Downloading pyedflib-0.1.40.tar.gz (2.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.3/2.3 MB 20.9 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: numpy>=1.9.1 in /usr/local/lib/python3.11/dist-packages (from pyedflib) (2.0.2)
# Building wheels for collected packages: pyedflib
#   Building wheel for pyedflib (pyproject.toml) ... done
#   Created wheel for pyedflib: filename=pyedflib-0.1.40-cp311-cp311-linux_x86_64.whl size=2734979 sha256=23574bd687b3ef03c149421e88c2a489a7d7db798568f0e23172e4ba56d50485
#   Stored in directory: /root/.cache/pip/wheels/8d/df/d6/88ce619bde055ebffebae5380645802eca490817853b60b45b
# Successfully built pyedflib
# Installing collected packages: pyedflib
# Successfully installed pyedflib-0.1.40

# %%
import mne
import numpy as np
import torch
import os
import pyedflib
from google.colab import drive
from scipy.signal import butter, filtfilt
from sklearn.preprocessing import StandardScaler
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
from sklearn.preprocessing import StandardScaler

# %%
base_dir = "/content/drive/My Drive/4106 Project/eeg-motor-movementimagery-dataset-1.0.0/files"

# %%
def bandpass_filter(data, sfreq, low=0.5, high=40.0, order=4):
    nyq = 0.5 * sfreq
    low /= nyq
    high /= nyq
    b, a = butter(order, [low, high], btype='band')
    return filtfilt(b, a, data)

def load_events(event_file):
    events = []
    with open(event_file, 'r', encoding='latin-1') as f: # Changed encoding to 'latin-1'
        for line in f:
            parts = line.strip().split()
            if len(parts) >= 2:
                try:
                    timestamp = float(parts[0])
                    label = parts[1]
                    events.append((timestamp, label))
                except Exception as e:
                    print(f"Skipping line due to error: {e}")
    return events

# %%
edf_path = "/content/drive/My Drive/4106 Project/eeg-motor-movementimagery-dataset-1.0.0/files/S001/S001R01.edf"
raw = mne.io.read_raw_edf(edf_path, preload=True, verbose=False)

# Print channel names
print("Channels:", raw.ch_names)

# Print annotations (if present)
print("Annotations:", raw.annotations)

# Convert annotations to events (if needed)
events, event_id = mne.events_from_annotations(raw)
print("Event dictionary:", event_id)
print("Events array:\n", events)
# Out:
# Channels: ['Fc5.', 'Fc3.', 'Fc1.', 'Fcz.', 'Fc2.', 'Fc4.', 'Fc6.', 'C5..', 'C3..', 'C1..', 'Cz..', 'C2..', 'C4..', 'C6..', 'Cp5.', 'Cp3.', 'Cp1.', 'Cpz.', 'Cp2.', 'Cp4.', 'Cp6.', 'Fp1.', 'Fpz.', 'Fp2.', 'Af7.', 'Af3.', 'Afz.', 'Af4.', 'Af8.', 'F7..', 'F5..', 'F3..', 'F1..', 'Fz..', 'F2..', 'F4..', 'F6..', 'F8..', 'Ft7.', 'Ft8.', 'T7..', 'T8..', 'T9..', 'T10.', 'Tp7.', 'Tp8.', 'P7..', 'P5..', 'P3..', 'P1..', 'Pz..', 'P2..', 'P4..', 'P6..', 'P8..', 'Po7.', 'Po3.', 'Poz.', 'Po4.', 'Po8.', 'O1..', 'Oz..', 'O2..', 'Iz..']
# Annotations: <Annotations | 1 segment: T0 (1)>
# Used Annotations descriptions: [np.str_('T0')]
# Event dictionary: {np.str_('T0'): 1}
# Events array:
#  [[0 0 1]]

# %%
import os
import mne
import numpy as np

# Base folder
base_path = "/content/drive/My Drive/4106 Project/eeg-motor-movementimagery-dataset-1.0.0/files"

# Valid motor imagery recordings
valid_runs = ['R03', 'R04', 'R07', 'R08', 'R11', 'R12']

# Initialize data containers
X = []
y = []

# MNE parameters
tmin, tmax = 0.0, 2.0  # seconds for each epoch
# Desired number of time points per epoch
n_times = None

# Loop over all subject folders
for subject_folder in os.listdir(base_path):
    subject_path = os.path.join(base_path, subject_folder)
    if not os.path.isdir(subject_path):
        continue

    for edf_file in os.listdir(subject_path):
        if not edf_file.endswith(".edf"):
            continue

        if not any(run in edf_file for run in valid_runs):
            continue  # Skip rest or irrelevant runs

        edf_path = os.path.join(subject_path, edf_file)
        try:
            raw = mne.io.read_raw_edf(edf_path, preload=True, verbose=False)
            events, event_id = mne.events_from_annotations(raw)

            if len(events) == 0:
                print(f"No events found in {edf_file}")
                continue

            # Pick EEG channels only
            raw.pick_types(eeg=True)

            # Create epochs (2-second window from each event)
            epochs = mne.Epochs(raw, events, event_id=event_id,
                                tmin=tmin, tmax=tmax, baseline=None,
                                preload=True, verbose=False)

            labels = epochs.events[:, -1]  # Extract label IDs
            data = epochs.get_data()       # Shape: (n_epochs, n_channels, n_times)

            # Check and adjust the number of time points
            if n_times is None:
                n_times = data.shape[2]  # Set initial value
            elif data.shape[2] != n_times:
                # Either truncate or pad to match n_times
                if data.shape[2] > n_times:
                    data = data[:, :, :n_times]  # Truncate
                else:
                    pad_width = ((0, 0), (0, 0), (0, n_times - data.shape[2]))
                    data = np.pad(data, pad_width, mode='constant') # Pad with zeros

            X.append(data)
            y.append(labels)

            print(f"Processed {edf_file}: {data.shape[0]} samples")

        except Exception as e:
            print(f"Failed to process {edf_file}: {e}")

# Combine all data
if X:
    X = np.concatenate(X, axis=0)
    y = np.concatenate(y, axis=0)
    np.savez_compressed("/content/drive/My Drive/4106 Project/eeg_dataset.npz", X=X, y=y)
    print(f"\n✅ Compiled dataset: X shape = {X.shape}, y shape = {y.shape}")
else:
    print("⚠️ No valid samples were found.")
# Out:
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Processed S107R11.edf: 30 samples
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Processed S107R07.edf: 30 samples
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Processed S107R03.edf: 30 samples
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Processed S107R12.edf: 30 samples
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Processed S107R04.edf: 30 samples
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Processed S107R08.edf: 30 samples
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Processed S101R12.edf: 30 samples
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Processed S101R03.edf: 30 samples
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Processed S101R04.edf: 30 samples
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Processed S101R08.edf: 30 samples
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Processed S101R07.edf: 30 samples
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Processed S101R11.edf: 30 samples
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Processed S105R11.edf: 30 samples
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Processed S105R03.edf: 30 samples
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Processed S105R12.edf: 30 samples
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Processed S105R04.edf: 30 samples
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Processed S105R07.edf: 30 samples
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Processed S105R08.edf: 30 samples
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Processed S108R04.edf: 30 samples
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Processed S108R07.edf: 30 samples
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Processed S108R08.edf: 30 samples
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Processed S108R11.edf: 30 samples
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Processed S108R12.edf: 30 samples
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Processed S108R03.edf: 30 samples
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Processed S102R04.edf: 30 samples
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Processed S102R07.edf: 30 samples
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Processed S102R11.edf: 30 samples
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Processed S102R12.edf: 30 samples
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Processed S102R03.edf: 30 samples
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Processed S102R08.edf: 30 samples
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Processed S103R12.edf: 30 samples
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Processed S103R03.edf: 30 samples
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Processed S103R11.edf: 30 samples
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Processed S103R08.edf: 30 samples
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Processed S103R07.edf: 30 samples
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Processed S103R04.edf: 30 samples
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Processed S109R03.edf: 30 samples
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Processed S109R04.edf: 30 samples
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Processed S109R07.edf: 30 samples
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Processed S109R12.edf: 30 samples
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Processed S109R11.edf: 30 samples
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Processed S109R08.edf: 30 samples
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Processed S104R08.edf: 26 samples
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Processed S104R07.edf: 30 samples
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Processed S104R12.edf: 30 samples
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Processed S104R04.edf: 30 samples
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Processed S104R11.edf: 30 samples
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Processed S104R03.edf: 30 samples
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# <ipython-input-8-29e554970e05>:35: RuntimeWarning: Limited 1 annotation(s) that were expanding outside the data range.
#   raw = mne.io.read_raw_edf(edf_path, preload=True, verbose=False)
# Processed S100R08.edf: 24 samples
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# <ipython-input-8-29e554970e05>:35: RuntimeWarning: Limited 1 annotation(s) that were expanding outside the data range.
#   raw = mne.io.read_raw_edf(edf_path, preload=True, verbose=False)
# Processed S100R07.edf: 24 samples
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# <ipython-input-8-29e554970e05>:35: RuntimeWarning: Limited 1 annotation(s) that were expanding outside the data range.
#   raw = mne.io.read_raw_edf(edf_path, preload=True, verbose=False)
# Processed S100R04.edf: 24 samples
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# <ipython-input-8-29e554970e05>:35: RuntimeWarning: Limited 1 annotation(s) that were expanding outside the data range.
#   raw = mne.io.read_raw_edf(edf_path, preload=True, verbose=False)
# Processed S100R12.edf: 24 samples
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# <ipython-input-8-29e554970e05>:35: RuntimeWarning: Limited 1 annotation(s) that were expanding outside the data range.
#   raw = mne.io.read_raw_edf(edf_path, preload=True, verbose=False)
# Processed S100R11.edf: 24 samples
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# <ipython-input-8-29e554970e05>:35: RuntimeWarning: Limited 1 annotation(s) that were expanding outside the data range.
#   raw = mne.io.read_raw_edf(edf_path, preload=True, verbose=False)
# Processed S100R03.edf: 24 samples
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Processed S106R12.edf: 30 samples
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Processed S106R08.edf: 30 samples
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Processed S106R07.edf: 30 samples
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Processed S106R11.edf: 30 samples
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Processed S106R03.edf: 30 samples
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Processed S106R04.edf: 30 samples
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Processed S092R07.edf: 38 samples
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Processed S092R04.edf: 38 samples
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Processed S092R08.edf: 38 samples
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Processed S092R11.edf: 38 samples
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Processed S092R03.edf: 38 samples
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Processed S092R12.edf: 38 samples
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Processed S095R07.edf: 30 samples
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Processed S095R08.edf: 30 samples
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Processed S095R12.edf: 30 samples
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Processed S095R03.edf: 30 samples
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Processed S095R11.edf: 30 samples
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Processed S095R04.edf: 30 samples
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Processed S096R12.edf: 30 samples
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Processed S096R11.edf: 30 samples
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Processed S096R04.edf: 30 samples
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Processed S096R08.edf: 30 samples
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Processed S096R07.edf: 30 samples
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Processed S096R03.edf: 30 samples
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Processed S097R12.edf: 30 samples
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Processed S097R11.edf: 30 samples
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Processed S097R07.edf: 30 samples
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Processed S097R08.edf: 30 samples
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Processed S097R04.edf: 30 samples
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Processed S097R03.edf: 30 samples
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Processed S091R11.edf: 30 samples
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Processed S091R08.edf: 30 samples
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Processed S091R12.edf: 30 samples
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Processed S091R03.edf: 30 samples
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Processed S091R07.edf: 30 samples
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Processed S091R04.edf: 30 samples
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Processed S098R12.edf: 30 samples
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Processed S098R07.edf: 30 samples
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Processed S098R08.edf: 30 samples
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Processed S098R03.edf: 30 samples
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Processed S098R11.edf: 30 samples
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Processed S098R04.edf: 30 samples
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Processed S090R12.edf: 30 samples
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Processed S090R03.edf: 30 samples
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Processed S090R04.edf: 30 samples
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Processed S090R07.edf: 30 samples
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Processed S090R11.edf: 30 samples
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Processed S090R08.edf: 30 samples
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Processed S093R07.edf: 30 samples
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Processed S093R03.edf: 30 samples
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Processed S093R08.edf: 30 samples
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Processed S093R12.edf: 30 samples
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Processed S093R11.edf: 30 samples
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Processed S093R04.edf: 30 samples
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Processed S094R07.edf: 30 samples
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Processed S094R11.edf: 30 samples
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Processed S094R04.edf: 30 samples
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Processed S094R03.edf: 30 samples
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Processed S094R08.edf: 30 samples
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Processed S094R12.edf: 30 samples
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Processed S099R04.edf: 30 samples
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Processed S099R11.edf: 30 samples
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Processed S099R07.edf: 30 samples
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Processed S099R12.edf: 30 samples
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Processed S099R03.edf: 30 samples
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Processed S099R08.edf: 30 samples
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Processed S081R12.edf: 30 samples
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Processed S081R08.edf: 30 samples
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Processed S081R03.edf: 30 samples
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Processed S081R07.edf: 30 samples
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Processed S081R04.edf: 30 samples
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Processed S081R11.edf: 30 samples
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Processed S089R07.edf: 30 samples
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Processed S089R04.edf: 30 samples
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Processed S089R12.edf: 30 samples
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Processed S089R11.edf: 30 samples
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Processed S089R03.edf: 44 samples
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Processed S089R08.edf: 30 samples
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Processed S082R04.edf: 30 samples
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Processed S082R07.edf: 30 samples
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Processed S082R12.edf: 30 samples
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Processed S082R11.edf: 30 samples
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Processed S082R03.edf: 30 samples
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Processed S082R08.edf: 30 samples
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Processed S083R07.edf: 30 samples
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Processed S083R03.edf: 30 samples
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Processed S083R08.edf: 30 samples
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Processed S083R12.edf: 30 samples
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Processed S083R04.edf: 30 samples
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Processed S083R11.edf: 30 samples
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Processed S080R08.edf: 30 samples
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Processed S080R03.edf: 30 samples
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Processed S080R04.edf: 30 samples
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Processed S080R11.edf: 30 samples
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Processed S080R07.edf: 30 samples
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Processed S080R12.edf: 30 samples
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Processed S085R07.edf: 30 samples
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Processed S085R04.edf: 30 samples
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Processed S085R11.edf: 30 samples
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Processed S085R03.edf: 30 samples
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Processed S085R12.edf: 30 samples
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Processed S085R08.edf: 30 samples
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Processed S087R11.edf: 30 samples
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Processed S087R12.edf: 30 samples
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Processed S087R08.edf: 30 samples
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Processed S087R07.edf: 30 samples
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Processed S087R04.edf: 30 samples
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Processed S087R03.edf: 30 samples
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Processed S084R08.edf: 30 samples
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Processed S084R04.edf: 30 samples
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Processed S084R07.edf: 30 samples
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Processed S084R03.edf: 30 samples
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Processed S084R11.edf: 30 samples
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Processed S084R12.edf: 30 samples
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Processed S086R11.edf: 30 samples
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Processed S086R08.edf: 30 samples
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Processed S086R04.edf: 30 samples
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Processed S086R03.edf: 30 samples
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Processed S086R12.edf: 30 samples
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Processed S086R07.edf: 30 samples
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Processed S088R12.edf: 38 samples
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Processed S088R08.edf: 38 samples
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Processed S088R04.edf: 38 samples
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Processed S088R07.edf: 38 samples
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Processed S088R03.edf: 38 samples
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Processed S088R11.edf: 38 samples
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Processed S077R03.edf: 30 samples
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Processed S077R07.edf: 30 samples
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Processed S077R08.edf: 30 samples
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Processed S077R04.edf: 30 samples
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Processed S077R11.edf: 30 samples
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Processed S077R12.edf: 30 samples
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Processed S079R08.edf: 30 samples
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Processed S079R03.edf: 30 samples
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Processed S079R12.edf: 30 samples
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Processed S079R11.edf: 30 samples
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Processed S079R04.edf: 30 samples
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Processed S079R07.edf: 30 samples
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Processed S071R12.edf: 30 samples
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Processed S071R08.edf: 30 samples
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Processed S071R04.edf: 30 samples
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Processed S071R03.edf: 30 samples
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Processed S071R07.edf: 30 samples
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Processed S071R11.edf: 30 samples
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Processed S076R04.edf: 30 samples
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Processed S076R07.edf: 30 samples
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Processed S076R12.edf: 30 samples
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Processed S076R08.edf: 30 samples
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Processed S076R11.edf: 30 samples
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Processed S076R03.edf: 30 samples
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Processed S072R12.edf: 30 samples
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Processed S072R08.edf: 30 samples
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Processed S072R04.edf: 30 samples
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Processed S072R07.edf: 30 samples
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Processed S072R03.edf: 30 samples
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Processed S072R11.edf: 30 samples
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Processed S078R12.edf: 30 samples
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Processed S078R07.edf: 30 samples
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Processed S078R03.edf: 30 samples
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Processed S078R04.edf: 30 samples
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Processed S078R08.edf: 30 samples
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Processed S078R11.edf: 30 samples
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Processed S073R03.edf: 30 samples
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Processed S073R07.edf: 30 samples
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Processed S073R04.edf: 30 samples
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Processed S073R08.edf: 30 samples
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Processed S073R12.edf: 30 samples
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Processed S073R11.edf: 30 samples
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Processed S075R08.edf: 30 samples
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Processed S075R04.edf: 30 samples
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Processed S075R12.edf: 30 samples
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Processed S075R11.edf: 30 samples
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Processed S075R03.edf: 30 samples
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Processed S075R07.edf: 30 samples
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Processed S074R04.edf: 30 samples
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Processed S074R12.edf: 30 samples
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Processed S074R07.edf: 30 samples
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Processed S074R08.edf: 30 samples
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Processed S074R03.edf: 30 samples
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Processed S074R11.edf: 30 samples
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Processed S070R08.edf: 30 samples
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Processed S070R07.edf: 30 samples
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Processed S070R04.edf: 30 samples
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Processed S070R11.edf: 30 samples
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Processed S070R03.edf: 30 samples
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Processed S070R12.edf: 30 samples
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Processed S063R04.edf: 30 samples
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Processed S063R11.edf: 30 samples
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Processed S063R12.edf: 30 samples
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Processed S063R03.edf: 30 samples
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Processed S063R08.edf: 30 samples
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Processed S063R07.edf: 30 samples
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Processed S064R11.edf: 30 samples
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Processed S064R04.edf: 30 samples
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Processed S064R07.edf: 30 samples
# ...
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Processed S014R04.edf: 30 samples
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Processed S011R04.edf: 30 samples
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Processed S011R07.edf: 30 samples
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Processed S011R03.edf: 30 samples
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Processed S011R12.edf: 30 samples
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Processed S011R11.edf: 30 samples
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Processed S011R08.edf: 30 samples
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Processed S017R07.edf: 30 samples
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Processed S017R03.edf: 30 samples
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Processed S017R08.edf: 30 samples
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Processed S017R04.edf: 30 samples
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Processed S017R12.edf: 30 samples
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Processed S017R11.edf: 30 samples
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Processed S012R12.edf: 30 samples
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Processed S012R11.edf: 30 samples
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Processed S012R04.edf: 30 samples
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Processed S012R03.edf: 30 samples
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Processed S012R07.edf: 30 samples
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Processed S012R08.edf: 30 samples
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Processed S019R11.edf: 30 samples
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Processed S019R04.edf: 30 samples
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Processed S019R07.edf: 30 samples
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Processed S019R12.edf: 30 samples
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Processed S019R08.edf: 30 samples
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Processed S019R03.edf: 30 samples
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Processed S013R12.edf: 30 samples
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Processed S013R03.edf: 30 samples
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Processed S013R11.edf: 30 samples
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Processed S013R04.edf: 30 samples
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Processed S013R08.edf: 30 samples
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Processed S013R07.edf: 30 samples
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Processed S001R08.edf: 30 samples
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Processed S001R12.edf: 30 samples
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Processed S001R04.edf: 30 samples
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Processed S001R11.edf: 30 samples
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Processed S001R07.edf: 30 samples
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Processed S001R03.edf: 30 samples
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Processed S003R03.edf: 30 samples
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Processed S003R11.edf: 30 samples
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Processed S003R12.edf: 30 samples
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Processed S003R08.edf: 30 samples
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Processed S003R04.edf: 30 samples
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Processed S003R07.edf: 30 samples
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Processed S007R07.edf: 30 samples
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Processed S007R11.edf: 30 samples
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Processed S007R08.edf: 30 samples
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Processed S007R12.edf: 30 samples
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Processed S007R04.edf: 30 samples
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Processed S007R03.edf: 30 samples
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Processed S004R12.edf: 30 samples
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Processed S004R04.edf: 30 samples
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Processed S004R07.edf: 30 samples
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Processed S004R08.edf: 30 samples
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Processed S004R03.edf: 30 samples
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Processed S004R11.edf: 30 samples
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Processed S009R11.edf: 30 samples
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Processed S009R08.edf: 30 samples
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Processed S009R04.edf: 30 samples
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Processed S009R12.edf: 30 samples
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Processed S009R07.edf: 30 samples
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Processed S009R03.edf: 30 samples
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Processed S008R03.edf: 30 samples
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Processed S008R12.edf: 30 samples
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Processed S008R07.edf: 30 samples
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Processed S008R11.edf: 30 samples
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Processed S008R04.edf: 30 samples
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Processed S008R08.edf: 30 samples
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Processed S005R04.edf: 30 samples
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Processed S005R08.edf: 30 samples
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Processed S005R12.edf: 30 samples
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Processed S005R11.edf: 30 samples
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Processed S005R03.edf: 30 samples
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Processed S005R07.edf: 30 samples
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Processed S002R11.edf: 30 samples
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Processed S002R08.edf: 30 samples
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Processed S002R03.edf: 30 samples
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Processed S002R07.edf: 30 samples
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Processed S002R12.edf: 30 samples
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Processed S002R04.edf: 30 samples
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Processed S006R12.edf: 30 samples
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Processed S006R11.edf: 30 samples
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Processed S006R03.edf: 30 samples
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Processed S006R07.edf: 30 samples
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Processed S006R08.edf: 30 samples
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Processed S006R04.edf: 30 samples
#
# ✅ Compiled dataset: X shape = (19690, 64, 321), y shape = (19690,)
